# %%
import pandas as pd
import numpy as np

# %%
dataset_train       = pd.read_parquet("dataset/train.parquet")
dataset_validation  = pd.read_parquet("dataset/validation.parquet")

# %%
print(dataset_train.keys())

dataset_train["lang"]
# Out:
# Index(['question', 'context', 'lang', 'answerable', 'answer_start', 'answer',
#        'answer_inlang'],
#       dtype='object')
# 0        bn
# 1        bn
# 2        bn
# 3        bn
# 4        bn
#          ..
# 15321    te
# 15322    te
# 15323    te
# 15324    te
# 15325    te
# Name: lang, Length: 15326, dtype: object

# %% [markdown]
# ## Week 36

# %% [markdown]
# ### a)

# %%
def summarize_statistics(df):

    print(f'Total number of rows: {len(df)}')
    print(f'Labels are: {df.keys()}')

    num_fi = df.loc[df["lang"] == "fi"].shape[0]
    num_ja = df.loc[df["lang"] == "ja"].shape[0]
    num_ru = df.loc[df["lang"] == "ru"].shape[0]

    num_questions = {'fi':num_fi, 'ja':num_ja, 'ru':num_ru}

    print(f'Number of questions per language: {num_questions}')

    num_fi_ans = df.loc[(df["lang"] == "fi") & (df["answerable"])].shape[0]
    num_ja_ans = df.loc[(df["lang"] == "ja") & (df["answerable"])].shape[0]
    num_ru_ans = df.loc[(df["lang"] == "ru") & (df["answerable"])].shape[0]

    num_questions_ans = {'fi':num_fi_ans, 'ja':num_ja_ans, 'ru':num_ru_ans}
    percentajes = {'fi':num_fi_ans*1.0/num_fi, 'ja':num_ja_ans*1.0/num_ja, 'ru':num_ru_ans*1.0/num_ru}

    print(f'Number of answerable questions per language: {num_questions_ans}')
    print(f'Percentaje of answerable questions: {percentajes}')

    num_fi_mean_ans_start = df.loc[(df["lang"] == "fi") & (df["answerable"])]["answer_start"].mean()
    num_ja_mean_ans_start = df.loc[(df["lang"] == "ja") & (df["answerable"])]["answer_start"].mean()
    num_ru_mean_ans_start = df.loc[(df["lang"] == "ru") & (df["answerable"])]["answer_start"].mean()

    mean_ans_start = {'fi':float(num_fi_mean_ans_start), 'ja':float(num_ja_mean_ans_start), 'ru':float(num_ru_mean_ans_start)}

    print(f'Average start of the answer in context in answerable questions: {mean_ans_start}')

    num_fi_mean_context_len = float(df.loc[(df["lang"] == "fi") & (df["answerable"])]["context"].apply(lambda row: len(row)).mean())
    num_ja_mean_context_len = float(df.loc[(df["lang"] == "ja") & (df["answerable"])]["context"].apply(lambda row: len(row)).mean())
    num_ru_mean_context_len = float(df.loc[(df["lang"] == "ru") & (df["answerable"])]["context"].apply(lambda row: len(row)).mean())

    mean_context_len = {'fi': num_fi_mean_context_len, 'ja':num_ja_mean_context_len, 'ru':num_ru_mean_context_len}

    print(f'Average length of context in answerable questions: {mean_context_len}')

    context_lengths = df["context"].apply(lambda row: len(row))
    mean    = float(context_lengths.mean())
    variance= float(context_lengths.var()) 

    print(f'Mean length of context: {mean}')
    print(f'Variance in length of context: {variance}')
    
print("----------------------------[Train]----------------------------")
summarize_statistics(dataset_train)
print("----------------------------[Validation]----------------------------")
summarize_statistics(dataset_validation)
# Out:
# ----------------------------[Train]----------------------------
# Total number of rows: 15326
# Labels are: Index(['question', 'context', 'lang', 'answerable', 'answer_start', 'answer',
#        'answer_inlang'],
#       dtype='object')
# Number of questions per language: {'fi': 2126, 'ja': 2301, 'ru': 1983}
# Number of answerable questions per language: {'fi': 1872, 'ja': 1929, 'ru': 1756}
# Percentaje of answerable questions: {'fi': 0.8805268109125117, 'ja': 0.8383311603650587, 'ru': 0.8855269793242562}
# Average start of the answer in context in answerable questions: {'fi': 166.58226495726495, 'ja': 167.73613271124935, 'ru': 203.73234624145786}
# Average length of context in answerable questions: {'fi': 614.7708333333334, 'ja': 619.270088128564, 'ru': 627.6714123006834}
# Mean length of context: 613.0135064596111
# Variance in length of context: 164329.30794154407
# ----------------------------[Validation]----------------------------
# Total number of rows: 3028
# Labels are: Index(['question', 'context', 'lang', 'answerable', 'answer_start', 'answer',
#        'answer_inlang'],
#       dtype='object')
# Number of questions per language: {'fi': 528, 'ja': 456, 'ru': 396}
# Number of answerable questions per language: {'fi': 392, 'ja': 293, 'ru': 299}
# Percentaje of answerable questions: {'fi': 0.7424242424242424, 'ja': 0.6425438596491229, 'ru': 0.7550505050505051}
# Average start of the answer in context in answerable questions: {'fi': 168.35714285714286, 'ja': 163.4334470989761, 'ru': 167.77257525083613}
# Average length of context in answerable questions: {'fi': 633.3698979591836, 'ja': 586.0989761092151, 'ru': 561.1538461538462}
# Mean length of context: 618.3645970937913
# Variance in length of context: 133410.88717700972

# %% [markdown]
# ### b)

# %%
#Preprocessing to put everythin in lowercase:

dataset_train["question"] = dataset_train["question"].apply(lambda row: row.lower())
dataset_validation["question"] = dataset_validation["question"].apply(lambda row: row.lower())

# %%
#Takes a long time to execute

from transformers import AutoTokenizer, MarianMTModel, AutoTokenizer


model_name_fi = 'Helsinki-NLP/opus-mt-fi-en'
model_name_ja = 'Helsinki-NLP/opus-mt-ja-en'
model_name_ru = 'Helsinki-NLP/opus-mt-ru-en'


model_fi = MarianMTModel.from_pretrained(model_name_fi)
model_ja = MarianMTModel.from_pretrained(model_name_ja)
model_ru = MarianMTModel.from_pretrained(model_name_ru)


tokenizer_fi = AutoTokenizer.from_pretrained(model_name_fi)
tokenizer_ja = AutoTokenizer.from_pretrained(model_name_ja)
tokenizer_ru = AutoTokenizer.from_pretrained(model_name_ru)
tokenizer_en = AutoTokenizer.from_pretrained("bert-base-cased")

sample_text = "Miten voin käyttää tätä käännösmallia?"

def translate(text,tokenizer,model):
    batch = tokenizer([text], return_tensors="pt")
    generated_ids = model.generate(**batch)
    return tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]




questions_fi = dataset_train.loc[(dataset_train["lang"] == "fi")]["question"].apply(lambda row: translate(row,tokenizer_fi,model_fi))
questions_ja = dataset_train.loc[(dataset_train["lang"] == "ja")]["question"].apply(lambda row: translate(row,tokenizer_ja,model_ja))
questions_ru = dataset_train.loc[(dataset_train["lang"] == "ru")]["question"].apply(lambda row: translate(row,tokenizer_ru,model_ru))
# Out:
# c:\Users\daniel\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
tokenized_questions_fi = questions_fi.apply(lambda row: tokenizer_en.tokenize(row)).to_list()
tokenized_questions_ja = questions_ja.apply(lambda row: tokenizer_en.tokenize(row)).to_list()
tokenized_questions_ru = questions_ru.apply(lambda row: tokenizer_en.tokenize(row)).to_list()

def count_word_frequency(sequences):
    frequencies = {}
    for row in sequences:
        for word in row:
            if word in frequencies:
                frequencies[word] += 1
            else: 
                frequencies[word] = 1
    return dict(sorted(frequencies.items(), key=lambda x:x[1], reverse=True))

word_count_fi = count_word_frequency(tokenized_questions_fi)
word_count_ja = count_word_frequency(tokenized_questions_ja)
word_count_ru = count_word_frequency(tokenized_questions_ru)

# %% [markdown]
# ### c)

# %%
from transformers import AutoTokenizer, MarianMTModel, AutoTokenizer


model_name_fi = 'Helsinki-NLP/opus-mt-fi-en'
model_name_ja = 'Helsinki-NLP/opus-mt-ja-en'
model_name_ru = 'Helsinki-NLP/opus-mt-ru-en'


model_fi = MarianMTModel.from_pretrained(model_name_fi)
model_ja = MarianMTModel.from_pretrained(model_name_ja)
model_ru = MarianMTModel.from_pretrained(model_name_ru)


tokenizer_fi = AutoTokenizer.from_pretrained(model_name_fi)
tokenizer_ja = AutoTokenizer.from_pretrained(model_name_ja)
tokenizer_ru = AutoTokenizer.from_pretrained(model_name_ru)


def translate(text,tokenizer,model):
    batch = tokenizer([text], return_tensors="pt")
    generated_ids = model.generate(**batch)
    return tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]




questions_fi = dataset_validation.loc[(dataset_validation["lang"] == "fi")]["question"].apply(lambda row: translate(row,tokenizer_fi,model_fi))
questions_ja = dataset_validation.loc[(dataset_validation["lang"] == "ja")]["question"].apply(lambda row: translate(row,tokenizer_ja,model_ja))
questions_ru = dataset_validation.loc[(dataset_validation["lang"] == "ru")]["question"].apply(lambda row: translate(row,tokenizer_ru,model_ru))
# Out:
# c:\Users\daniel\AppData\Local\Programs\Python\Python312\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
context_fi = dataset_validation.loc[(dataset_validation["lang"] == "fi")]["context"]
context_ja = dataset_validation.loc[(dataset_validation["lang"] == "ja")]["context"]
context_ru = dataset_validation.loc[(dataset_validation["lang"] == "ru")]["context"]

X_fi = pd.concat([questions_fi,context_fi], axis=1)
X_ja = pd.concat([questions_ja,context_ja], axis=1)
X_ru = pd.concat([questions_ru,context_ru], axis=1)

X = pd.concat([X_fi,X_ja,X_ru],axis = 0)

def rule_based_predictor(row):


    question = row["question"]
    context  = row["context"]

    
    #Functions to check type of question
    def contains_what(question):
        return "what" in question.lower()
    def contains_where(question):
        return "where" in question.lower()
    def contains_who(question):
        return "who" in question.lower()
    def contains_why(question):
        return "why" in question.lower()
    def contains_when(question):
        return "when" in question.lower()
    def contains_yes_no(question):
        return question.lower().startswith(("is", "are"))
    def contains_how(question):
        return "how" in question.lower()
    

    #Functions to guess if context answers specific type
    
    if contains_what(question):
        return answers_what(context)
    if contains_where(question):
        return answers_where(context)
    if contains_who(question):
        return answers_who(context)
    if contains_how(question):
        return answers_how(context)
    if contains_why(question):
        return answers_why(context)
    if contains_when(question):
        return answers_when(context)
    return False

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
display(questions_fi)
# Out:
# 311              What country was Jack Churchill born in?
# 312        What is the most common religion in the world?
# 313                      Who was the star of Glee's show?
# 314     When was the Killzone series game first released?
# 315                  When did Pennsylvania join the U.S.?
# 316                   Where did Richard Attenborough die?
# 317                                When was atheism born?
# 318              Where does digital television come from?
# 319                 Have Finnish dialects always existed?
# 320                          Who played the lead in Glee?
# 321             What is Jaco Pastorius' most famous song?
# 322     Are the peaks of the Andes completely covered ...
# 323                What town was Mario Cipollini born in?
# 324     When did the Silver Arrow Manga start publishing?
# 325     With what dynasty did the so-called Mandarins ...
# 326                    Where did nominalism get its name?
# 327              What grain is Ouzo's basic raw material?
# 328                            Who started functionalism?
# 329     Which NHL founding teams are still in the league?
# 330         When did Bernard Montgomery become a marshal?
# 331     Did Great Britain wage war during Jaakko I's r...
# 1431             How many countries does the WWF work in?
# 1432      Where was England’s royal wedding held in 1947?
# 1433                                  Who was Thrasyllos?
# 1435                        What does the Reichstag mean?
# 1436    What is the most ordered newspaper in Finland ...
# 1437    How many TV shows did Lost complete during the...
# 1438             When did they start selling Moomin mugs?
# 1440                              Is nuclear waste toxic?
# 1442    Has Grenada struck several destructive hurrica...
# 1443                     How many vessels do people have?
# 1447      What was the first direction of the Hope Basin?
# 1451                      Where's Nintendo's head office?
# 1456            How many colors are on the Nigerian flag?
# 1457                  How do you earn a Mannerheim cross?
# 1459           How many parts of a human brain are there?
# 1465    What year did Keijo Rosberg win the last F1 se...
# 1468    Where is the largest airport in the area of Ep...
# 1470        What year was the ship HMS Ramillies wrecked?
# 1474               When have africans developed the term?
# 1477         What is the largest municipality in Finland?
# 1478                        What are the symptoms of JBS?
# 1479    Which countries took part in the North African...
# 1480        What city of Norway is known as the oil city?
# 1481                                   What's Vaudeville?
# 1483      How many islands are there in the Cook Islands?
# 1485    What year was HMS Belvoir placed on the deprec...
# 1486         Where was John Brown and Company's shipyard?
# 1487         How many countries is Kazakhstan limited to?
# 1488    When was Madagascar’s battle during World War II?
# 1489    In what modern country is ancient northern Thr...
# 1493                    When did man start using a horse?
# 1494    Why has Russia had a central bank office in He...
# 1496                     What is Bhutan's state religion?
# 1498                      Where does the virus come from?
# 1499                           When was Sevastopol taken?
# 1502                   Where did Alkibiades get his name?
# 1503        Where did the spinning birds get their names?
# 1504       Who came up with the idea of a stable economy?
# 1505    How many games does the Final Fantasy series i...
# 1506    Was William Pitt a successful British prime mi...
# 1507    Where was the first head office of the Auto Un...
# 1510             What year was Valve Corporation founded?
# 1511            How many speakers are there in Gudzharat?
# 1512                  Can the Atlantic Sea reach Finland?
# 1513                  Where did James Prescott Joule die?
# 1514                   Where did phenomenology come from?
# 1517    When did Brunei get his independence after the...
# 1520           Where did the Mayflower ship get its name?
# 1522                  Who was in charge of Decius before?
# 1524                                What are the hornets?
# 1528                     What did Thomas Macaulay die of?
# 1529     To what diseases can ionizing radiation be used?
# 1531    Has Anderson "The Spider" Silva won the World ...
# 1533         When was the first airport built in Finland?
# 1534    How many times did Katharine Hepburn run for O...
# 1535    Which country on the American continent has th...
# 1539             Why did the Finnish civil war break out?
# 1540                          Is there a call in Denmark?
# 1543                Did Albert Einstein ever get married?
# 1546               How do you define a half-bear species?
# 1548    What was the first agricultural machine in Fin...
# 1553             What is Emily Bronte's most famous poem?
# 1558     What is the smallest planet in our solar system?
# 1560    What year did English musician Richard Wright ...
# 1562                       When did the GP2 series start?
# 1563     What is the most common definition of a village?
# 1564          How many royal families have ruled England?
# 1565                             Which sex is determined?
# 1567              Who created the character Lilo Pelekai?
# 1568                      When is Final Fantasy released?
# 1569                   What year was Hiromu Arakawa born?
# 1570    How many games does the Final Fantasy series i...
# 1571                     What year was DC Comics founded?
# 1577        What is the most common religion among Arabs?
# 1578                   What year was space first studied?
# 1579                     What year was Tom Fletcher born?
# 1580               What year did industrialization begin?
# 1582                                    What's an affect?
# 1584         Where was John Brown and Company's shipyard?
# 1585             When did they start selling Moomin mugs?
# 1586                   What country owns Solomon Islands?
# 1591                            When is Kalevala written?
# 1596                Who has developed the interpretation?
# 1597                  When were the radio waves detected?
# 1599             What was the first film made in Finland?
# 1605    When did Brunei get his independence after the...
# 1608    Do we need neutrons to produce radioactive mat...
# 1609                        Who created Thor's character?
# 1610         Which city was Camillo Benso di Cavour from?
# 1611                           Who founded Studio Ghibli?
# 1613       Who came up with the idea of a stable economy?
# 1614                          How dangerous is the X-ray?
# 1615                      What Indians built Teotihuacán?
# 1617                         Are there tribes in Bolivia?
# 1618    How many primetime Emmy awards did the TV show...
# 1620    What is the most popular car model in the Unit...
# 1621                  Is Time Measuring Physics Research?
# 1625                             When was NTFS developed?
# 1628         What does that mean, "transitional element"?
# 1630                          How many species are there?
# 1631      Is Shin Megami Tensei: Persona 4 Japanese game?
# 1635    Did the Northwest Russian army cooperate with ...
# 1637                         How do you define my castle?
# 1638    In what modern - day country was the battle fo...
# 1640                             How old can a wolf live?
# 1645    When did Hollywood become the center of the fi...
# 1646                      When is Final Fantasy released?
# 1648                 What's the population of Versailles?
# 1649    Why did the Lithuanian Socialist Soviet Republ...
# 1650               Where was Abbasidic Caliphate founded?
# 1651    What is the population of Greece to the neares...
# 1656                  Who developed the first laser beam?
# 1658    When is the first piece of legislation registe...
# 1661           What country company is Valve Corporation?
# 1663      What year has Japan developed its first weapon?
# 1665              Who was the prince of Kiev before Igor?
# 1666                     What's James Bond's special car?
# 1669      How many years can you get in jail for killing?
# 1670                       What's the South African area?
# 1672                          How are the planets formed?
# 1675    What is the most famous literary product of an...
# 1676                                        Where's Niue?
# 1677    When did the French Revolutionary Wars take pl...
# 1678                     What year was DC Comics founded?
# 1681    Why did the People’s Front of Palestine Libera...
# 1686                            When is Kalevala written?
# 1688                                   What's an Omnibus?
# 1690                What is the population of Korpilahti?
# 1691    Is Islam’s theology of faith narrower than Chr...
# 1692                      When did Gioachino Rossini die?
# 1693                   What year did Albert Reynolds die?
# 1694         Where was the geometric structure developed?
# 1697                   Is agriculture practiced in Japan?
# 1699      What's the idea of the Half-Life computer game?
# 1701       What is the most common religion in the world?
# 1702             How many classes have you had in Sweden?
# 1703             What is the most mined metal in Finland?
# 1705    How many years did Rutherford Birchard Hayes s...
# 1707                 Who wrote the Ready Player One book?
# 1708                  What's the synonym of a neurotoxin?
# 1711                       Are there dialects in Russian?
# 1712                       What year was Silovik founded?
# 1715    What is the most densely populated state of th...
# 1718                          What is Thai national food?
# 1720    What year did the Netherlands introduce their ...
# 1721                      What is generally built of oak?
# 1727         How many organs are in the digestive system?
# 1728                     What has Peter Benenson studied?
# 1732    What political party did Patrick Henry Pearse ...
# 1737                       What year was PowerPark built?
# 1742      Is Shin Megami Tensei: Persona 4 Japanese game?
# 1743            How does personality disorder come about?
# 1744                           How is scholastic defined?
# 1745                             Who built the west wall?
# 1753                       What's the South African area?
# 1754                      What was Bhutan's surface area?
# 1756                 Where does the name Teela come from?
# 1761    What is the world’s oldest religion that is st...
# 1764                          What is Thai national food?
# 1765        What is the fastest ship or boat of all time?
# 1766       What is a well-known statement by the Marines?
# 1767    Did the Northwest Russian army cooperate with ...
# 1768    What were the wider effects of the Russian-Jap...
# 1769                      What does the jackal look like?
# 1772                            What color are sapphires?
# 1776    When did Curt Lincoln start his professional c...
# 1777    How many prisoners are sentenced to death in t...
# 1778               How long is the so-called long bridge?
# 1781                     Where was Arne Treholt captured?
# 1784                Can a person live without a pancreas?
# 1785            How many speakers are there in Gudzharat?
# 1787                   What does the term symbiosis mean?
# 1788              Who played the lead in the escape show?
# 1789            Did Martin Heidegger teach Hannah Arendt?
# 1790                   How high can a cross-sypress grow?
# 1791    What year did the Netherlands introduce their ...
# 1792                What happened in Porvoo's parliament?
# 1793                What year has Iceland been inhabited?
# 1795     What year was the Soviet space programme set up?
# 1798    How many soldiers were in the Roman army of An...
# 1800                  Does Agent Carter have superpowers?
# 1802           Where did the horses come from in Finland?
# 1804         What state of the United States is Portland?
# 1805    Was Tarja Halone's first female president in t...
# 1807                            Can a person make silver?
# 1809    What country had the world's first female pres...
# 1810                     Where was the crossbow invented?
# 1811      How much vitamin K does a person need in a day?
# 1815                   What countryman was Sigmund Freud?
# 1816                     Why Lola Montez fled to the U.S.
# 1817                Who has developed a linear-a writing?
# 1822    Why has the ninth member of Girls’ Generation ...
# 1823                        When was the mirror invented?
# 1824               What decade did the gnostic come from?
# 1825    Who was the head of the Finnish Defence Forces...
# 1826                When did they start using guillotine?
# 1827                When did the DDR2 come to the market?
# 1828    In the vicinity of what city did Hitler spend ...
# 1829                  Where does an earthquake come from?
# 1831    How much of the largest country in China has a...
# 1832                           How do you define a model?
# 1833                       How old is science philosophy?
# 1834                       How is a mascaradento defined?
# 1835                          When did Lauri Leander die?
# 1837    How many production seasons have you finished ...
# 1838    Where did Wade Barrett start his show wrestlin...
# 1839                           Who were the Plantagenets?
# 1840    When did the master of Dibley Church begin to ...
# 1841                        When was Cosa Nostra founded?
# 1842    What year was Volkswagen Transporter T3 launched?
# 1843                        What's my Carrie novel about?
# 1845          What war ended in the peace of Nuts Island?
# 1846          What is the northernmost city in the world?
# 1847    How many provinces have Catalonia been divided...
# 1848    In what modern - day country was the battle fo...
# 1850         What's the most listening song in Anthestor?
# 1851              Who owns Wilhelmsen Ship Management AS?
# 1853                When did the DDR3 come to the market?
# 1854                                   Who was Mona Lisa?
# 1855         What's the biggest moon in the solar system?
# 1856                                  When's Kanda's day?
# 1857           Is forced sterilization legal in the U.S.?
# 2030    Why did the People’s Front of Palestine Libera...
# 2032    Why did the Soviet Union have financial problems?
# 2033                          Are pigs raised in Finland?
# 2034                How many anxiety disorders are there?
# 2035              Where does the term finipods come from?
# 2036                        Where was New Sweden located?
# 2037                       Who founded the Finnish State?
# 2038    Where did Wade Barrett start his show wrestlin...
# 2039    Are helicopters used much in military operations?
# 2041    What was Katherine Anne “Kate” Austen’s charac...
# 2042      Since when do the Sámi colonize Fennoscandians?
# 2045                    When was the SI system developed?
# 2049    How many major species does the animal kingdom...
# 2050                  How long is it for an ancient wolf?
# 2051    Was there an international war crime court dur...
# 2052                         How do you define an empire?
# 2055                       Is folic acid toxic to humans?
# 2061        What year was the ship HMS Ramillies wrecked?
# 2063       When did they come up with traffic telematics?
# 2065                When did they start using guillotine?
# 2066    Why did the Soviet Union have financial problems?
# 2069    What year did Keijo Rosberg win the last F1 se...
# 2072    When was the Killzone series game first released?
# 2073                               What's a box of wings?
# 2074                      How many works did Ibn Arab do?
# 2077              When was the icebreaker Power launched?
# 2081            What is the bishop's most important task?
# 2082            What is the bishop's most important task?
# 2084                       Can global warming be stopped?
# 2085                 When did the capitolium wolf finish?
# 2086           When was the concept of Topology invented?
# 2090    How many categories of vehicles are in use in ...
# 2091    How many times has Jari-Matti Latvala won the ...
# 2094                             Who invented Sabo-Tabby?
# 2097           Do you have any alkali metals in the wild?
# 2098                                Who invented Finnish?
# 2099    How many different countries does a citizen dr...
# 2102                                Are the spikes sharp?
# 2104                           Who started functionalism?
# 2105                          How fast does space expand?
# 2107                    When was diabetes first observed?
# 2110       Which country was found to be an ancient wolf?
# 2111       Where did the name "The Teflon Don" come from?
# 2112        What size are the planets in the Kuiper zone?
# 2114          How many planets is the earth from the sun?
# 2116         What year did the Watchwork Orange come out?
# 2121                       Are there dialects in Russian?
# 2123    What was the purpose of Barmen’s Theological D...
# 2129                   When has rice wine been developed?
# 2130                               When was atheism born?
# 2131    How many Oscar Awards has One Flew Over Cuckoo...
# 2132              How much money is spent on the average?
# 2133                           When was Sevastopol taken?
# 2134                    When was the SI system developed?
# 2135                     When was the burlesque invented?
# 2142    What language did the angels of the Old Testam...
# 2143    When did the Ford Mustang model begin to be bu...
# 2149    Is Jamie Foxx playing the Horrible Bosses in t...
# 2154                      How is a symphony poem defined?
# 2155              When was the icebreaker Power launched?
# 2157                       What does the human wave mean?
# 2159               When did the first Saturn IB graduate?
# 2160           What country company is Valve Corporation?
# 2162                                   Who was Mona Lisa?
# 2163                           What makes beer alcoholic?
# 2166         When did Viktor Brotherus become a botanist?
# 2167    What was previously referred to as psychiatry ...
# 2168                             Who founded New Zealand?
# 2169         Which Finn played Cercle Bruges in the '80s?
# 2170    Who signed the Moscow Peace Treaty on behalf o...
# 2172                             How high is the Neckula?
# 2173    How much of the largest country in China has a...
# 2175    Was The Pleasure Garden originally a silent film?
# 2176                What happened in Porvoo's parliament?
# 2180                 Does Calcutta have poisonous snakes?
# 2181                    How many teams do the mucus have?
# 2186                     What's James Bond's special car?
# 2189                 How many moons does the Saturn have?
# 2190             What was Peter Laird's first comic book?
# 2191      What year has Japan developed its first weapon?
# 2192                               How is oxytan defined?
# 2193                Did Albert Einstein ever get married?
# 2195        When was the concept of job suction invented?
# 2197           Where did the horses come from in Finland?
# 2198    What year has Stephen King written The Shining...
# 2201                  When were the radio waves detected?
# 2202        How important was Verona in the Roman Empire?
# 2203             What year did William R. Catton Jr. die?
# 2204                  What is the most common amino acid?
# 2205              Where does the term sitadell come from?
# 2208                             Who invented the guitar?
# 2209                      What is generally built of oak?
# 2210    When did man begin to exploit the horse in the...
# 2211                                 Is the penis muscle?
# 2212     What is the smallest planet in our solar system?
# 2215             Where did the Colombian Civil War begin?
# 2219                Have Finnish dialects always existed?
# 2226                       What is Brazil's surface area?
# 2229      What's the idea of the Half-Life computer game?
# 2231               When have africans developed the term?
# 2235    After the third division of Poland, did the Po...
# 2240                  What is the surface area of Europe?
# 2241             Where did the Colombian Civil War begin?
# 2242              Who played Superman in Superman movies?
# 2243                When did the DDR3 come to the market?
# 2246    Are the bonds between molecules stronger than ...
# 2247                        Who created Thor's character?
# 2628            How many colors are on the Nigerian flag?
# 2629    Who was in charge of the Confederacy in the Un...
# 2630         What does that mean, "transitional element"?
# 2631    Why did the Lithuanian Socialist Soviet Republ...
# 2632    When did the master of Dibley Church begin to ...
# 2633                          When was East Rome founded?
# 2634    When did the story of the founding of Rome begin?
# 2635                      Where's Nintendo's head office?
# 2636           Where did the horses come from in Finland?
# 2637                           How do you define a model?
# 2638            How does personality disorder come about?
# 2639                              What do amino acids do?
# 2640            How many speakers are there in Gudzharat?
# 2641    Has Anderson "The Spider" Silva won the World ...
# 2642           Has Antti Karhula played hockey in France?
# 2643                   Is Peter Jackson from New Zealand?
# 2644      Is the northern part of Serbia a fertile plain?
# 2645    Is the head of state the same thing as the pre...
# 2646    Are the bonds between molecules stronger than ...
# 2647            How many colors are on the Nigerian flag?
# 2648    Who was in charge of the Confederacy in the Un...
# 2649         What does that mean, "transitional element"?
# 2650    Why did the Lithuanian Socialist Soviet Republ...
# 2651                          When was East Rome founded?
# 2652    What year did Italy apply to be a member of th...
# 2653             What year did William R. Catton Jr. die?
# 2654                 Where was Sampo-Rosenlew Oy founded?
# 2655           Where did the horses come from in Finland?
# 2656                           How do you define a model?
# 2657            How does personality disorder come about?
# 2658                              What do amino acids do?
# 2659                          What does the Admiral mean?
# 2660    Has Anderson "The Spider" Silva won the World ...
# 2661           Has Antti Karhula played hockey in France?
# 2662      Is the northern part of Serbia a fertile plain?
# 2663    Is the head of state the same thing as the pre...
# 2664            How many colors are on the Nigerian flag?
# 2665    Who was George H.W. Bush's opponent in the pre...
# 2666    Why did the Lithuanian Socialist Soviet Republ...
# 2667    What was the main objective of the Russian Red...
# 2668                          When was East Rome founded?
# 2669    When did the story of the founding of Rome begin?
# 2670                 Where was Sampo-Rosenlew Oy founded?
# 2671                      Where's Nintendo's head office?
# 2672           Where did the horses come from in Finland?
# 2673                         How do you define my castle?
# 2674                           How do you define a model?
# 2675            How does personality disorder come about?
# 2676                              What do amino acids do?
# 2677                          What does the Admiral mean?
# 2678            How many speakers are there in Gudzharat?
# 2679    Has Anderson "The Spider" Silva won the World ...
# 2680           Has Antti Karhula played hockey in France?
# 2681                   Is Peter Jackson from New Zealand?
# 2682      Is the northern part of Serbia a fertile plain?
# 2683    Is the head of state the same thing as the pre...
# 2684    How many games does the Final Fantasy series i...
# 2685    How many German soldiers participated in Germa...
# 2686            How many colors are on the Nigerian flag?
# 2687    Who was in charge of the Confederacy in the Un...
# 2688    Who was George H.W. Bush's opponent in the pre...
# 2689    Why did the Lithuanian Socialist Soviet Republ...
# 2690    What was the main objective of the Russian Red...
# 2691                       What is Brazil’s largest city?
# 2692              What flood occurred in Finland in 2007?
# 2693    When did the master of Dibley Church begin to ...
# 2694    When was the Killzone series game first released?
# 2695    When did the story of the founding of Rome begin?
# 2696    What year was HMS Belvoir placed on the deprec...
# 2697         What year did the Watchwork Orange come out?
# 2698                     What year was Tom Fletcher born?
# 2699             What year did William R. Catton Jr. die?
# 2700                 Where was Sampo-Rosenlew Oy founded?
# 2701                      Where's Nintendo's head office?
# 2702           Where did the horses come from in Finland?
# 2703                         How do you define my castle?
# 2704            How does personality disorder come about?
# 2705                          What does the Admiral mean?
# 2706            How many speakers are there in Gudzharat?
# 2707    Has Anderson "The Spider" Silva won the World ...
# 2708           Has Antti Karhula played hockey in France?
# 2709                   Is Peter Jackson from New Zealand?
# 2710      Is the northern part of Serbia a fertile plain?
# 2711    Is the head of state the same thing as the pre...
# 2712    How many games does the Final Fantasy series i...
# 2713            How many colors are on the Nigerian flag?
# 2714    Who was in charge of the Confederacy in the Un...
# 2715    When was the Killzone series game first released?
# 2716                     What year was Tom Fletcher born?
# 2717                          What does the Admiral mean?
# 2718      Is the northern part of Serbia a fertile plain?
# 2719                           Do you live in the Baltic?
# 2720                   Is agriculture practiced in Japan?
# 2721                          Are pigs raised in Finland?
# 2722                             Which sex is determined?
# 2723                   How did the tyranny of Athens end?
# 2724             How many countries does the WWF work in?
# 2725    How many times has Jari-Matti Latvala won the ...
# 2726    How many times did Katharine Hepburn run for O...
# 2727    How many politicians are there in the Finnish ...
# Name: question, dtype: object

# %%
display(context_fi)
# Out:
# 311     Churchill was born at Colombo, British Ceylon ...
# 312     The five largest religious groups by world pop...
# 313     Rachel Barbra Berry (Lea Michele) is the lead ...
# 314     Killzone is a series of first-person shooter a...
# 315     The state is one of the 13 original founding s...
# 316     In June 2012, shortly before her 90th birthday...
# 317     In early ancient Greek, the adjective ' (, fro...
# 318     Digital television (DTV) is the transmission o...
# 319     Westrobothnian () is a number of closely relat...
# 320     Rachel Barbra Berry (Lea Michele) is the lead ...
# 321     Birdland marked the peak of Weather Report's c...
# 322     The climate in the Andes varies greatly depend...
# 323     Cipollini was born in Lucca, Tuscany. He came ...
# 324     Takahashi was born September 18, 1953, in Higa...
# 325     China has had civil servants since at least th...
# 326     The term 'nominalism' stems from the Latin "no...
# 327     Ouzo (, ) is a dry anise-flavoured aperitif th...
# 328     The broad position of "functionalism" can be a...
# 329     The National Hockey League was established in ...
# 330     Winston Churchill had Montgomery promoted to f...
# 331     The war became deadlocked around the turn of t...
# 2192    Occitania (, , , ) is the historical region an...
# 2193    Elsa Einstein (18 January 1876 – 20 December 1...
# 2195    Generally, work engagement is conceptualized a...
# 2197    The exact origins of the early Finnish horse a...
# 2198    The Shining is a horror novel by American auth...
# 2201    This phenomenon was first observed in a 1938 e...
# 2202    Verona is famous for its Roman amphitheatre, t...
# 2203                      Catton died on January 5, 2015.
# 2204    In human blood, glutamine is the most abundant...
# 2205    A citadel is the core fortified area of a town...
# 2208    Electric guitars can have solid, semi-hollow, ...
# 2209    Oak wood has a density of about creating great...
# 2210    How and when horses became domesticated is dis...
# 2211    The retractor penis muscle occurs in marsupial...
# 2212    Kepler-37b is an extrasolar planet (exoplanet)...
# 2215    The origin of the armed conflict in Colombia g...
# 2219    The most important contributions to improving ...
# 2226    Brazil ( ), officially the Federative Republic...
# 2229    Half-Life (stylized as HλLF-LIFE) is a first-p...
# 2231    The first recorded instance of a colonist iden...
# 2235    In 1795, a Third Partition of Poland was under...
# 2240    Europe covers about , or 2% of the Earth's sur...
# 2241    The Colombian Civil War began on May 8, 1860, ...
# 2242    Christopher Reeve played Superman/Clark Kent i...
# 2243    DDR3 prototypes were announced in early 2005. ...
# 2246    Intermolecular forces (IMF) are the forces whi...
# 2247    Debuting in the Silver Age of Comic Books, the...
# 2628    The flag of Nigeria is the official flag of th...
# 2629    New Orleans, however, surrendered to the Union...
# 2630    The transition state is the point on the react...
# 2631    From 1940 to 1990, the Lithuanian Soviet Socia...
# 2632    The Vicar of Dibley () is a British sitcom cre...
# 2633    around the 14th century BC. The urbanization o...
# 2634    The story of the founding of Rome is a fable t...
# 2635    by October 2, 2008. In addition to its hardwar...
# 2636    they could not be scheduled. Linguists also co...
# 2637    A miniature model is a significantly smaller c...
# 2638    Personality disorders are developmental condit...
# 2639    Amino acids are organic compounds that have bo...
# 2640    Gujarati is an Indo-Aryan language. Most of it...
# 2641    Anderson da Silva (born April 14, 1975), also ...
# 2642    Antti Karhula (born March 23, 1976 in Oulu) is...
# 2643    Sir Peter Jackson (born October 31, 1961 in Pu...
# 2644    Croatia is geographically divided into three p...
# 2645    The head of state (also head of state) is the ...
# 2646    The bond number describes the degree of bondin...
# 2647    The flag of Niger is the symbol of Niger toget...
# 2648    all Confederate forces had surrendered by the ...
# 2649    In nuclear magnetic resonance-based NMR spectr...
# 2650    The Lithuanian Soviet Socialist Republic (, , ...
# 2651    The Roman Empire (often also ancient Rome) was...
# 2652    The Italian region has been the core region of...
# 2653    enrolled at Oberlin College, where he met Nanc...
# 2654    Wilhelm Rosenlew from Pori founded W. Rosenlew...
# 2655    from running, trotting and galloping. Each fea...
# 2656    A miniature room is a one-room dollhouse, i.e....
# 2657    Personality is a whole made up of thoughts, fe...
# 2658    Omega-3 fatty acids are polyunsaturated fatty ...
# 2659    Vice admiral (abbreviated v-amir) is a high mi...
# 2660    the defending and longest-serving champion. Si...
# 2661    Tero Karhu (born September 28, 1979 in Helsink...
# 2662    private sector is seen as a chance for improve...
# 2663    president. In general, the president is the co...
# 2664    The flag of Sudan was introduced on May 20, 19...
